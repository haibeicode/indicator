# %%
from indicator.technology.average import *
import tushare as ts
df = ts.get_hist_data('000001')
df.tail()
# Out:
#             open  high  close   low     volume  price_change  p_change    ma5  \
# date
# 2017-01-09  9.13  9.17   9.15  9.11  361081.56          0.02      0.22  9.154
# 2017-01-06  9.17  9.17   9.13  9.11  358154.19         -0.04     -0.44  9.155
# 2017-01-05  9.17  9.18   9.17  9.15  344372.91          0.01      0.11  9.163
# 2017-01-04  9.15  9.18   9.16  9.14  449329.53          0.00      0.00  9.160
# 2017-01-03  9.11  9.18   9.16  9.09  459840.47          0.06      0.66  9.160
#
#              ma10   ma20      v_ma5     v_ma10     v_ma20
# date
# 2017-01-09  9.154  9.154  394555.73  394555.73  394555.73
# 2017-01-06  9.155  9.155  402924.28  402924.28  402924.28
# 2017-01-05  9.163  9.163  417847.64  417847.64  417847.64
# 2017-01-04  9.160  9.160  454585.00  454585.00  454585.00
# 2017-01-03  9.160  9.160  459840.47  459840.47  459840.47

# %%
# 多空均线
BBI(df, 3, 6, 12, 24).tail()
# Out:
#                  BBI
# date
# 2017-01-09  9.190625
# 2017-01-06  9.183125
# 2017-01-05  9.181771
# 2017-01-04  9.179167
# 2017-01-03  9.180312

# %%
# 指数平均线
EXPMA(df, 5, 10, 20, 60).tail()
# Out:
#                  MA1       MA2       MA3       MA4
# date
# 2017-01-09  9.153199  9.182978  9.243852  9.303860
# 2017-01-06  9.145466  9.173346  9.233009  9.298160
# 2017-01-05  9.153644  9.172737  9.227008  9.293958
# 2017-01-04  9.155763  9.170421  9.220626  9.289566
# 2017-01-03  9.157175  9.168527  9.214852  9.285318

# %%
# 高价平均线
HMA(df, 6, 12, 30, 72, 144).tail()
# Out:
#                 HMA1      HMA2      HMA3      HMA4      HMA5
# date
# 2017-01-09  9.170000  9.198333  9.366000  9.310972  9.489861
# 2017-01-06  9.171667  9.189167  9.352667  9.313194  9.476389
# 2017-01-05  9.170000  9.182500  9.339667  9.315556  9.462569
# 2017-01-04  9.171667  9.178333  9.325000  9.318333  9.447917
# 2017-01-03  9.173333  9.173333  9.311667  9.320972  9.433750

# %%
# 低价平均线
LMA(df, 6, 12, 30, 72, 144).tail()
# Out:
#                 LMA1      LMA2      LMA3      LMA4      LMA5
# date
# 2017-01-09  9.116667  9.137500  9.262667  9.224583  9.347778
# 2017-01-06  9.123333  9.130000  9.250333  9.226667  9.335278
# 2017-01-05  9.128333  9.125833  9.238667  9.229722  9.323125
# 2017-01-04  9.130000  9.123333  9.225333  9.233194  9.310694
# 2017-01-03  9.123333  9.118333  9.215000  9.235833  9.297639

# %%
# 变异平均线
VMA(df, 6, 12, 30, 72, 144).tail()
# Out:
#                 VMA1      VMA2      VMA3      VMA4      VMA5
# date
# 2017-01-09  9.143750  9.166667  9.314583  9.268264  9.417830
# 2017-01-06  9.146250  9.158333  9.301833  9.270417  9.404826
# 2017-01-05  9.148750  9.153542  9.289000  9.273194  9.391875
# 2017-01-04  9.150833  9.150208  9.275250  9.276181  9.378403
# 2017-01-03  9.149167  9.146458  9.263583  9.278819  9.364861

# %%
# 成本价均线
AMV(df, 5, 13, 34, 60).tail()
# Out:
#                 AMV1      AMV2      AMV3      AMV4
# date
# 2017-01-09  9.143820  9.170737  9.325576  9.302934
# 2017-01-06  9.143542  9.164345  9.317502  9.302611
# 2017-01-05  9.150151  9.157407  9.310649  9.302946
# 2017-01-04  9.153149  9.152475  9.301719  9.302197
# 2017-01-03  9.149303  9.148069  9.292213  9.301563

# %%
# 多空布林线
BBIBOLL(df, 11, 6).tail()
# Out:
#              BBIBOLL       UPR       DWN
# date
# 2017-01-09  9.190625  9.564535  8.816715
# 2017-01-06  9.183125  9.514203  8.852047
# 2017-01-05  9.181771  9.441944  8.921597
# 2017-01-04  9.179167  9.411274  8.947059
# 2017-01-03  9.180312  9.379922  8.980703

# %%
# 鳄鱼线
ALLIGAT(df, 11, 6).tail()
# Out:
#                SC        YC        XE
# date
# 2017-01-09  9.142  9.171667  9.306818
# 2017-01-06  9.140  9.159167  9.296818
# 2017-01-05  9.144  9.150833  9.281818
# 2017-01-04  9.149  9.143333  9.265909
# 2017-01-03  9.146  9.141667  9.253182
